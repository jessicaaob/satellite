# %% [markdown]
# # Install Packages

# %%
#pip install in venv as usual
import pandas as pd

# %%
#in standard python library, do not need to pip install
from glob import glob

# %%
# pip install in venv
# 21sec import time
import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep

# %%
#no pip required
import rasterio as rio

# %%
# no pip required
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap

# %%
# pip install plotly in venv
import plotly.graph_objects as go

# %% [markdown]
# # Read Data

# %%
np.seterr(divide='ignore', invalid='ignore')
S_sentinel_bands = glob("../data/external/images/*B?*.tiff")
S_sentinel_bands.sort()

# %% [markdown]
# # Visualise Bands

# %%
l = []
for i in S_sentinel_bands:
    with rio.open(i, 'r') as f:
        l.append(f.read(1))
arr_st = np.stack(l)
ep.plot_bands(arr_st, cmap = 'gist_earth', figsize = (20, 12), cols = 6, cbar = False)
plt.show()

# %% [markdown]
# # RGB Composite Image

# %%
rgb = ep.plot_rgb(arr_st, 
                  rgb=(3,2,1), 
                  figsize=(10, 16))
plt.show()
